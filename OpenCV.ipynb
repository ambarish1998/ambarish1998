# %%
import cv2

# %%
import imutils

# %%
import pytesseract

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
from matplotlib import pyplot as plt

img = cv2.imread(r'G:\GATE\product.jpeg')
image = imutils.resize(img, width =500)

plt.imshow(img)
plt.title('my picture')
plt.show()

# %%
grey_image = cv2.cvtColor(image , cv2.COLOR_BGR2GRAY)
plt.imshow(grey_image)
plt.show()
cv2.waitKey(0)
# Out:
# -1

# %%
edged = cv2.Canny(grey_image , 170, 200)
plt.imshow(edged)
plt.show()
cv2.waitKey(0)
# Out:
# -1

# %%
cnts , new = cv2.findContours(edged.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
cnts = sorted(cnts, key = cv2.contourArea , reverse = True )[:30]
image1 = image.copy()
cv2.drawContours(image1, cnts, -1,(0,255,0),3)
plt.imshow(image1)
plt.show()
cv2.waitKey(0)
# Out:
# -1

# %%
counture_with_lisenceplate = None
lisence_Plate = None
x = None
y = None
w = None
h = None

# %%
image2 = image1.copy()
cv2.drawContours(image2, cnts, -1 ,(0,255,0),3)
plt.imshow(image2)
plt.show()
cv2.waitKey(0)
# Out:
# -1

# %%
count= 0 
name = 1

# %%
for i in cnts:
    perimeter = cv2.arcLength(i , True)
    approx = cv2.approxPolyDP(i, 0.01*perimeter, True)
    if(len(approx) == 4):
        counture_with_lisenceplate = approx
        x, y, w, h = cv2.boundingRect(i)
        lisence_Plate = grey_image[y:y+h, x:x+w]
        break

# %%
plt.imshow(lisence_Plate)
plt.show()
cv2.waitKey(0)
# Out:
# -1

# %%
text = pytesseract.image_to_string(lisence_Plate)

# %%
print(text)
# Out:
# -CGOAMF2250,
